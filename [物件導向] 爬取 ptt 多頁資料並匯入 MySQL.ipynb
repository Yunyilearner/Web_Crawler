# %% [markdown]
# <font color = #00efff size = 5 face="標楷體"> 匯入函式庫(模組) </font>

# %%
#爬蟲相關套件
import requests
from bs4 import BeautifulSoup
import time

#資料處理與儲存相關套件
import pandas as pd
from IPython.display import display
import numpy as np
import re, random, time, os

#資料庫連結操作 pymysql.connections 
import pymysql
from sqlalchemy import create_engine

#------------------------------------------------
#Not every package has a __version__ attribute.
import sys
print('python version = ', sys.version)
from importlib.metadata import version
print('requests version = ', version('requests')) #same as (requests.__version__)
print('pandas version = ', pd.__version__)
print('pymysql version = ', version('pymysql'))
# Out:
# python version =  3.9.16 (main, Jan 11 2023, 16:16:36) [MSC v.1916 64 bit (AMD64)]
# requests version =  2.29.0
# pandas version =  1.5.3
# pymysql version =  1.0.2

# %% [markdown]
# <font color = #ff6f00 size = 5 face="Times New Roman"> 定義 PttCrawler 類，爬取 PTT 指定討論板多頁 HTML </font>
# * 大部分代碼解釋請參閱 **爬取 PTT 多頁資料與貼文內容**
#
# * Instance Attribute:
# >1. theme : 由參數賦值，討論板主題。
# >2. total_page : 由參數賦值，爬取總頁數。
# >3. start_page :  PTT 討論版爬取起始頁。
# >4. latest_page :　PTT 討論版的最新頁數，由 get_latest_pttpage() 賦值。
# >5. last_page : PTT 討論版爬取末頁，預設是該討論版的`最新頁數`作為爬取末頁。
# >6. ptt_urls :　PTT 討論板多頁網址，為列表 (list) 型態，由 assemble_multipage_urls()賦值。
# >7. article_links : 文章內文的連結網址，為列表 (list) 型態。
# >8. posts_info : 貼文資訊，包括文章標題、作者、發文日期、推文數、文章超連結、貼文內容，為字典(dictionary)型態。
#
# * Instance Mehod:
# >1. get_latest_pttpage() : 取得 PPT 論壇中欲爬取之討論板的最新頁數。
# >2. assemble_multipage_urls() : 用來組合 PTT 多頁網址。
# >3. fetch_html(url_list = None) : 發送傳入參數之 HTTP 請求，參數須為存放網址的列表(list)，預設參數為 PTT 網址列表，回傳值為存放 BeautifulSoup 結構樹的字典: {index : BeautifulSoup物件} 。
# >4. get_posts_html():搜索 HTML 結構樹，並萃取出各貼文區塊標籤。
# >4. get_posts_info(): 搜索並萃取出目標標籤，取得 PTT 貼文資訊，包括:文章標題、作者、發文日期、推文數、文章超連結、貼文內容，以字典形式回傳。
# >5. get_posts_content(): 發送文章超連結請求，取得爬取到的文章內容，印出內文文字內容。

# %%
class Crawler_ptt:
    # 設定表頭偽裝成瀏覽器。(敘述太長以反斜線 '\' 分行方便閱讀)
    ptt_headers = {'over18':'1',          #一直向 server 回答滿 18 歲了 !
                    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)\
                    AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.84\
                    Safari/537.36'}
    
    def __init__(self, theme, total_page, last_page = None):
        self.theme = theme
        self.total_page = total_page
        self.latest_page = self.get_latest_pttpage()
        if last_page is None:
            self.last_page = self.latest_page
        else:
            self.last_page = last_page
        self.start_page = (self.last_page - self.total_page) + 1
        self.ptt_urls = self.assemble_multipage_urls()    #回傳組合好的網址賦值
        self.article_links = []    #存放貼文連結網址
        self.posts_info = {}    #存放貼文資訊
        
        
    def get_latest_pttpage(self): 
        """ 取得 PPT 論壇中欲爬取之討論板的最新頁數 """
        url = f'https://www.ptt.cc/bbs/{self.theme}/index.html'
        res = requests.get(url, headers = Crawler_ptt.ptt_headers)
        soup = BeautifulSoup(res.text, 'lxml')
        buttons = soup.find_all("a", class_ = "btn wide")
        for btn in buttons:
            if btn.text == '‹ 上頁':
                pre_url = btn["href"]
                pre_page = int(pre_url.split("/")[-1].split(".")[0].replace("index", ""))
                
                return pre_page + 1
        
            
    def assemble_multipage_urls(self):
        """ 用來組合討論版多頁網址，回傳網址列表賦值給 self.ptt_urls 
        """
        ptt_urls = []
        for p in range(self.start_page, self.last_page + 1):
            entire_url = f'https://www.ptt.cc/bbs/{self.theme}/index{p}.html'
            ptt_urls.append(entire_url)
            
        return ptt_urls
    
    
    def fetch_html(self, url_list = None):  
        """ 發送傳入參數之 HTTP 請求，參數須為存放網址的列表(list)型態，預設為 PTT 網址列表，
        回傳存放 BeautifulSoup 結構樹的字典: {index : BeautifulSoup物件} 
        """
        if url_list is None:
            url_list = self.ptt_urls    #預設參數傳入 self.ptt_urls
        else: 
            url_list = url_list
            
        bptree_dic = {}   #存放每頁網頁的 HTML 資料，{0:'BeautifulSoup1', 1:BeautifulSoup2,...}
        for i in range(len(url_list)):    
            try:
                r = requests.get(url_list[i], headers = Crawler_ptt.ptt_headers)
                bptree_dic[i] = BeautifulSoup(r.text, 'lxml') 
            except Exception as err:
                print('程式出現異常:', err)
                print(r.raise_for_status())
                print(r.reason)            
            else:
                # 確認請求是否成功
                if r.status_code == requests.codes.ok:  
                    print(f'{i+1}.成功取得 {url_list[i]} 資料')
                else:  
                    print(f'{i+1}.{url_list[i]} 取得失敗')
            if i % 50 == 0:time.sleep(random.uniform(2,4))

        return bptree_dic
    
    
    def get_posts_html(self):
        """ 搜索 HTML 結構樹，並萃取出各貼文區塊之標籤。
        """
        post_divs = []    #存放每篇貼文 html 區塊
        ptt_bp_dic = self.fetch_html()   #調用 fetch_html() 實體方法
        for k in ptt_bp_dic:    #一一取出字典中每頁 BeautifulSoup 資料  
            # 找出各篇貼文之 html 區塊
            post_divs += ptt_bp_dic[k].select('div.r-ent')
            
        return post_divs
    
            
    def get_posts_info(self):
        """取得 PTT 貼文資訊，包括:文章標題、作者、發文日期、推文數、文章超連結、文章內容，
        以字典形式回傳。
        """
        posts_html = self.get_posts_html()
        num = 1
        for post in posts_html:    
            if post != None:    #確認 post 不為空值
                title = post.find('div', class_='title').text.strip()
                link = post.select_one('.title a') 
                author = post.find('div', 'author').text.strip()
                post_date = post.find('div', 'date').text.strip()
                push_num = post.find('div', 'nrec').text.strip()
                if link is not None:
                    self.article_links.append(f'https://www.ptt.cc{link.get("href")}')
                else:
                    self.article_links.append('No link found')
                self.posts_info[f'No.{num}'] = {  
                    "title": title,
                    "author": author,
                    "post_date": post_date,
                    "push_num": push_num,
                    "article_links": link,
                    "content": '\n'}
                num += 1
            else: print('posts_html 為 None')
        self.get_posts_content()
      
        return self.posts_info
    
    
    def get_posts_content(self):
        """ 取得文章內容，列印出每一篇貼文文章內容。 
        """
        links_bp_dic = self.fetch_html(self.article_links)   #調用實體方法 fetch_html()，參數為文章超連結串列
        if len(self.posts_info) == len(self.article_links):    
            for l in links_bp_dic:    
                content_div = links_bp_dic[l].find('div', id = 'main-content')
                content_list = list(content_div)  #將 html 結構樹轉為列表
                for item in content_list:
                    if isinstance(item, str):
                        self.posts_info[f'No.{l+1}']['content'] += f'{item.strip()}'
                    elif item.has_attr('href'):
                        self.posts_info[f'No.{l+1}']['content'] += f'{item.text}' 
                print(f"第 {l+1} 篇: {self.posts_info[f'No.{l+1}']['content']}")
                print('=='*50)

        else:print('貼文數量與貼文連結數量不一致')

# %%
if __name__ == "__main__":
    #創建實體物件 
    cptt = Crawler_ptt('Soft_Job', 2)     
    #調用 get_posts_info()方法更新 self.article_links, self.posts_info，以及取得字典形式的貼文資訊，
    cptt.get_posts_info()
    #以表格形式顯示貼文資訊
    posts_df = pd.DataFrame(cptt.posts_info).T
    print(posts_df.info())
    display(posts_df)
# Out:
# 1.成功取得 https://www.ptt.cc/bbs/Soft_Job/index1754.html 資料
# 2.成功取得 https://www.ptt.cc/bbs/Soft_Job/index1755.html 資料
# 1.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683519326.A.3F7.html 資料
# 2.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683531484.A.FE0.html 資料
# 3.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683535626.A.5F2.html 資料
# 4.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683536591.A.983.html 資料
# 5.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683549816.A.BBA.html 資料
# 6.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683565711.A.B54.html 資料
# 7.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683596444.A.343.html 資料
# 8.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683606691.A.3AD.html 資料
# 9.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683637949.A.4AA.html 資料
# 10.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683640295.A.2BA.html 資料
# 11.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683707371.A.784.html 資料
# 12.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683716049.A.227.html 資料
# 13.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683727551.A.278.html 資料
# 14.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683760729.A.22A.html 資料
# 15.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683769158.A.4FD.html 資料
# 16.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683800128.A.7B0.html 資料
# 17.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683826898.A.13C.html 資料
# 程式出現異常: Invalid URL 'No link found': No scheme supplied. Perhaps you meant https://No link found?
# None
# OK
# 19.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683935349.A.04A.html 資料
# 20.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683963060.A.45C.html 資料
# 21.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1683998999.A.DBB.html 資料
# 22.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1684030323.A.640.html 資料
# 23.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1684074600.A.034.html 資料
# 24.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1684082846.A.C23.html 資料
# 25.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1501827536.A.DF2.html 資料
# 26.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1501827692.A.18D.html 資料
# 27.成功取得 https://www.ptt.cc/bbs/Soft_Job/M.1631270928.A.71A.html 資料
# 第 1 篇:
# 有做的其實比想像中的多，而且說賺的很大的也有
# 不常聽到的原因大概是因為你就跟那些人不在一個生活圈吧
# 正常來說
#
# 賺了不會上網跟大家說我今天賺了多少多少，自己繼續默默賺。誰知道上網分享會不會搞
# 到國稅局跑來邀請喝茶聊天
#
# 賠了也不會跟你講，都輸錢了還要特別跑出來跟大家說我是傻子錢都給莊家了，別像我一
# 樣
#
# 航海王是特例中的特例，更多的是也默默撈了個幾百萬幾千萬但不會說出來的
# 其實默默賺的還有很多，還有做一做自己跑出去開資產管理公司的
#
# 就像這篇我也不會跟你說我有沒有做，有沒有贏一樣
# 嘻嘻
#
# --哈哈嘻嘻又不是只玩台股原文說的是程式交易還是股票交易
# 全世界只剩股票市場可以玩喔科科我知道的基本一年都超過670，怎麼弄回來就很麻煩
# ====================================================================================================
# 第 2 篇:
# 其實這跟股板比較有關。
#
# 簡單說幾個我的觀點。
#
# 1. 會賺錢的方法自己賺都來不及，還會免費分享給你？
# 2. 掏金熱的時候賺錢的都是賣鏟子的人。
#
# 回到為何台灣個人工程師不太幹這種事？
#
# 先假設你有一個會賺錢的演算法，那接下來會有幾個問題。
#
# 1. 你的演算法會贏過大盤嗎？不會為何不買 ETF，
# 2. 你的本金夠嗎？不夠手續費或者api成本可能會吃垮你。
# 3. 如果因為本金不夠想貸款開槓桿，那房貸本身就是槓桿，何不買（ＲＹ。
#
# 更別提開發演算法跟寫程式都要成本了，租用機器跟 api 也要成本。
# 我的確有見過靠股票就財富自由的人，上次還在問我海外450萬上限繞過的方法。
# 不過這種人不靠程式交易也可以賺。
#
# 說穿了程式交易只是一種手段而非目的，二戰以前根本沒有電腦還不是可以炒股。
# 一點淺見供參考。
#
# --
# 乳不貧，何以平天下？乳不巨，何以聚人心？故，平天下者不得人心。
#
# --很多賣書的啊，天瓏很多我自己也買了幾本來看。
# ====================================================================================================
# 第 3 篇:
# 首先我就是讀商科 後來對寫程式有興趣
# 所以跳槽工程師
# 剛好又接觸到程式交易有興趣
# 後來就自己寫程式交易
# 只能說這門檻不低啊
# 我是剛好讀過財管 統計 計量 後來又自學演算法
#
# 一開始很長一段時間只能自己網上找資料摸索
# 台灣程式交易資訊不多
#  我大多去對岸或外國網站
# 所以要學習又要求英文門檻
# 一開始啥都不懂 花好長一段時間
# 各種網站自學 拼拼湊湊
# 才完整寫好自己的交易策略
# 而且還時不時要修正策略
#
# 程式交易不是隨便路人
# 跟你基本面籌碼面大談就好
# 反正嘴巴講講誰都會
# 但程式交易會就是會
# 程式碼騙不了人
# 不會裝會的問一下就被戳破
# 你隨便跟朋友談個回測的意義
# 沒在接觸程式交易的人誰知道你在供三小
# 連我當初論文是寫程式交易相關
# 因為我教授年紀比較大 一開始也不懂
#
# 連教授都可能不懂這塊了 何況要一般路人懂
# 而且會賺錢的策略幹嘛跟你分享
# 所以就知道外面賣交易策略的老師多可笑
# 會去買那課程的當韭菜也不意外
#
# --
# ====================================================================================================
# 第 4 篇:
# 我今年43歲，36歲從大陸回台灣，跟香港的姑姑一起合作開公司
# 40歲決裂自己工作，現在收入比開公司高。
#
# 所以如果能重新選擇一次，我不會作這個決定
#
# 跟家人的矛盾是最難處理的
# 情緒勒索
# 道德綁架
# 比比皆是
#
# 我一共跟四個人決裂：我爸、叔叔、堂弟、姑姑
#
# 只有我媽支持我了
#
# 其實我已經創過兩次了，
# 北京一次台灣一次，
# 學到最多的並不是技術或是管理技巧，
# 而是人性，
# 所謂人心難測，
# 就算是家人，或是好朋友，也有人性。
#
# 人性無善無惡，只是立場不同而已，
# 在平常也許是好朋友，但換了個位置，
# 立場不同，你會驚訝於為何人變得如此之快。
#
# 在歷經了親人、朋友的人情冷暖，也許你會成長，
# 也許會被傷害到一蹶不振，但你都要記住那是你的選擇，要自己扛。
#
# 所以我建議你，把自己當作一個單位，不論成敗都要自己能承擔起，
# 最好別有家裡當後盾的想法，這樣考慮做出來的決定，才是對你自己最好的。
#
# 尤其你提到的，爸爸的合夥人，合夥人的一度人脈關係，
# 其實你才是空降下來的大公子，他們都會想要怎麼面對你，
# 假如你沒有足夠的社交與溝通能力，會很辛苦。
#
# 人生是你自己的，就算是有父親當後盾，也永遠要準備自己的備案。
#
# 美國這件事，我覺得挺好，
# 多想想有沒有兩全其美的辦法，
# 如果你還有企圖心，應該是把自己當事業在經營，
# 把所有有利的條件都分析清楚，而不是用鄉愿或是情感作決定。
# 如果只是拘泥在字面上的『繼承家業』或是『美國打工』
# 那對你個人而言，其實並不能做出對你最好的決定
#
# 加油吧！身為過來人，我並不支持你繼承家業，
# 但我可以建議你，先當家裡的顧問，對國外公司爭取回台遠端福利，
# 從增加在台灣的時間開始磨合，
# 得到更多家裡這方面的資訊以後，或許你就能知道答案了。--
# ====================================================================================================
# 第 5 篇:
# 程式交易不少人在做，但工程師做程式交易的確實很少。
#
# 簡單來說，程式交易的金融部份，門檻並沒有很低，多數工程師都懂得不夠多，
# 所謂的不夠多，是說你不懂得怎麼開發策略，只能靠自己胡亂拼湊策略做回測，
# 這樣的實際執行結果，通常是贏不過大盤的。
#
# 只看理工科系背景的話，軟體工程師並沒有比其他人更強。
#
# 當然也許你的程式比較快，但 so what? HFT 是專業法人才玩得起的世界，
# 一般人不要幻想了，快那麼一點是沒有意義的。
#
# 相反的，對於學金融的人來說，只要會 python 就能試看看程式交易了，
# 甚至很多商管學院都有相關課程，對他們來說，這就只是一種技能，
# 喜不喜歡想不想做而已。
#
# 我公司一直在徵工程師，幾十份履歷裡也不見得有一個有程式交易經驗的，
# 其中多數還是台大電機或資工學歷的，一般的工程師幾乎都沒有經驗，
# 總不可能做過程式交易的工程師都賺了大錢，不想進 HFT/quant 公司吧？
# 照這個比例來推論，是真的很少。
#
# 另外以我高中同學的狀況來看，懂程式交易的醫生，比例可能都比較高，
# 讀資工的多半都是拚創業拚上市，誰要跟你玩程式交易。
#
# 所以囉，不夠強的通常玩不動，夠強的不見得有興趣。
#
#
# --IRR 沒有 50% 的就沒有認真是吧？
#
# 不要給人這種錢很好賺的幻象。某公司還宣傳過他們 alpha > 5,
# 甚至還有 alpha > 20 的策略呢，只看成功者當然一切都很美好。
# ====================================================================================================
# 第 6 篇:
# 問題在於你想要用程式幫到你交易的哪個部分？
#
# 如果你是要快進快出賺極短線的，你打得贏大公司的HFT嗎？ 交易成本賺得回來嗎？
#
# 配備不夠好資料不夠多就是去送錢給人家
#
# 如果你只是想要量化波段或長線進出場點，那已經有很多分析的系統可以直接使用
#
# 也不需要自己手寫程式花時間，波段長線的買賣也少，手動一季可能點個幾次而已
#
# 所以如果交易策略用程式並不會省事太多的話，也就不會有太多人去做了
#
# --
# ====================================================================================================
# 第 7 篇:
# 公司名稱，統編(中華民國以外註冊可免填):
#
# Swifteam
#
# Swifteam helps you manage the remote team’s onboarding/offboarding and device
#  purchasing, financing, approvals, storage, logistics, and management.
#
#
# 公司地址(填寫詳細至號):
#
# 4500 Great America Pkwy, Santa Clara, CA
#
#
# 職缺:
#
# Frontend Engineer(Vue)
# Backend Engineer(Golang)
#
#
# 職缺能力經歷要求:
#
# 【Frontend Engineer】
#
# 1年以上前端開發經驗，團隊使用Vue，但如果你是使用其他框架的也歡迎投遞履歷，只要
# 有自信能夠在進來後自行學習Vue
#
# 【Backend Engineer】
#
# 1年以上 Golang 經驗，或是有 Device mangagment(MDM) 的開發經驗
#
#
# 員工是否需自備工具? (是/否) :
#
# 否，可使用自己的設備，若有電腦或其他像螢幕需求，可跟老闆說，他會寄給你
#
#
# 薪資(年薪):
#
# - Frontend Engineer: 40k ~ 80k(USD) / year
# - Backend Engineer: 40k ~ 70k(USD) / year
#
#
# 薪資(保證最低年薪，必填項目):
# 12 個月
#
# 年終獎金計算方式:
# 無
#
# 工時:
# 每週40hr，理論上工作時間是 9:00~18:00，但因為全遠端，除了開會外其他時間可自行
# 安排
# 另外放假按照台灣行事曆
#
#
# 加班費制度：
# 加班有加班費，但目前還沒遇過需要加班的情況
#
#
# 工作環境與該職缺團隊介紹:
#
# 工作環境的話就看你想在哪上班，每週除了週一會開 sprint 會議外，基本上沒有其他會
# 議，有問題就私訊相關的同事，如果寫程式寫累了，中間想休息打個遊戲或出去走走散心
# 都沒問題，不會有人監督你。
#
# 老闆是台灣人，另外有幾個大陸同事，台灣及大陸同事會一起開會，所以是用中文開會，
# 團隊內還有一些非中文語系同事，如印度、土耳其..等等，所以文件以及通訊軟體上的文
# 字會以英文為主。
#
# 另外補充：英文的部分沒有到很要求，會需要用到英文溝通的情況也不算多，可能一週不
# 到一次，同事間大多都是用打字留訊息的方式，所以能夠Google翻譯的話就沒什麼大問題
# 唷
#
# 如果有想要特別練英文口說，也可以要求老闆都用英文跟你溝通xD
#
#
# 工作福利:
#
# - 全遠端工作，省去通勤塞車時間
# - 時間彈性，除了開會固定時間外，其餘時間都可自行安排(會議基本上都在半小時就結
# 束了)
# - 有來自各國的同事，算是一個練習英文口說很好的機會
#
#
# 公司分紅與獎金:
#
# 表現好的話會有股票選擇權
#
#
# 人資或徵才聯絡方式:
#
# 投遞履歷可透過 YComibantor 投遞，以下為連結：
# Frontend Engineer:https://reurl.cc/6Nojb6Backend Enginner:https://reurl.cc/EGxgmg或直接 Email 至老闆信箱[email protected]，來信請附上 cover letter，如只有傳
# 履歷會被過濾掉。
#
# PS: 因老闆人在美國，所以回覆的時間可能會比較晚。
#
# --
# ====================================================================================================
# 第 8 篇:
# 我一直覺得 Redis 在資料庫世界裡獨具一格。其他多數資料庫的中心思想不是表格就
# 是文件，但在 Redis 裡，你直接與鏈結串列（linked list）和雜湊表（hash table）
# 等低階資料結構打交道。
#
# 這個設計實在太奇妙了，我很好奇背後創作的故事，就花了一些時間研究，寫下這篇
# 故事。
#
# 圖文連結並茂版：https://blog.brachiosoft.com/redis臉書專頁：https://www.facebook.com/brachiosoftRedis 的獨創設計出自義大利的程式設計師 Salvatore Sanfilippo（網路名稱
# antirez）之手。精通系統程式設計的 antirez，喜歡用串列、雜湊、集合（set）等
# 資料結構來思考問題，表格或文件這種高階的資料表達方式不合他的味口。在創造
# Redis 時，antirez 是資料庫的門外漢，但也許就是他沒經驗，才能為資料庫領域帶
# 來新想法。
#
# 多年後的今天，Redis 已成為主流，幾乎所有網路服務背後都能見到它的蹤影。在
# Stack Overflow 的調查報告上，Redis 更是蟬聯五年最受愛戴的資料庫。
#
# ## antirez 早年生活
#
# antirez 在義大利西西里長大，小時候，他的父親在一間石化公司工作，擔任電工，
# 藉此接觸工業自動化的問題。80 年代，他父親開始使用可編程邏輯控制器（PLC），
# 並對這些控制器產生興趣，於是他買了一塊 Z80 處理器的板子，開始在上面寫程式。
#
# antirez 六歲時，家裡買了第一台個人電腦，TI-99/4A。那是一台商業上不成功
# ，但很有趣的電腦。他父親會那上面寫了一些 BASIC 程式，antirez 有樣學樣，小學
# 一年級時就會打鍵盤、複製 BASIC 程式等。
#
# 隨著年齡增長，antirez 繼續寫程式。到了 14 歲，青少年時期的興趣，像是摩托車
# 、女孩子，接踵而至，寫程式這個興趣就被拋諸腦後。直到 18-19 歲時，antirez 才
# 重拾對電腦的興趣，用電腦玩 3D 建模、遊戲，也寫一些簡單的程式。在巴勒摩大學
# 建築學院就讀大學時，他會用 BASIC 來畫圖。BASIC 是他兒時學過的程式語言，也是
# 他當時唯一會的語言。
#
# ## 資安公司 SECLAB
#
# 有一天，antirez 想買一張顯示卡，卻不小心買成了數據機，商家不肯退款，antirez
# 就順其自然：「數據機就數據機吧！」當時是 90 年代，網路逐漸平民化。他連上網
# 路，安裝了 Linux，開始對資訊安全產生興趣。他買了一本 C 語言的書，開始學習 C
# 語言。不久之後，他發現 ping 程式有一個漏洞。
#
# 這個漏洞是這樣的：在 Unix 裡通常有一個限制，如果你不是 root，則無法快速在短
# 時間內發送大量封包。但 antirez 發現透過 Unix 訊號，可以繞過這個限制。
#
# 他在 Bugtraq 郵件列表上發表這個發現，當時是 1998 年 4 月。Bugtraq 是一個關
# 於資安的郵件列表，全球的資安專家都會在上面發佈安全問題。隔天，antirez 接到
# 一通從米蘭打來的長途電話，一間名叫 SECLAB 的資安公司問他要不要來工作。
#
# antirez 受寵若驚：「但我只是一個建築系的大學生，我什麼都不懂。」但 SECLAB
# 的老闆還是鼓勵他來米蘭一趟，和他們聊聊。antirez 去了米蘭與他們見面，公司的
# 老闆告訴 antirez：「你回去繼續生活，但是讀這十本書，讀完再回來找我。」這十
# 本書都是關於網路的，如 TCP/IP 協定、防火牆、應用程式安全、密碼學等。1998 年
# 夏天，antirez 就每天西西里島的海邊讀這些書。
#
# 九月，antirez 回去找 SECLAB，他們想聘請 antirez。休學後，antirez 搬到米蘭工
# 作。第一次開會時，antirez 完全聽不懂同事在說什麼，冒牌者症候群油然而生。當
# 時義大利一些厲害的駭客都在 SECLAB 工作，在這充滿強者的環境裡，經過兩個月的
# 洗禮，antirez 也開始做出貢獻。
#
# 首先，antirez 發明了一種名為 Idle Scan 的攻擊手法。它至今仍是 Nmap 的著名的
# 攻擊手法之一，仍被人們研究著。SECLAB 的老闆認為 antirez 在開源社群的工作成
# 果，比去應付客戶有價值，就叫他不需煩惱客戶，只要專心寫開源軟體，在資安領域
# 研究攻擊手法。
#
# 此外，antirez 還寫了一個名叫 hping 的工具。它是一個可以讓你傳送客製 TCP/IP
# 封包的命令列工具，它的作用類似 ping，但它不一定要像 ping 走 ICMP 協定，所以
# hping 可以做到更多事。例如：測試防火牆規則、測試網路效能、繞過防火牆傳輸檔
# 案。
#
# 在 SECLAB 待了六個月之後，antirez 離開了。因為他開始晚睡，工作遲到，米蘭這
# 個大城市對一個 21 歲的年輕人實在太多采多姿，自治力不好很容易迷惘其中。雖然
# 時間短，期間 antirez 寫了很多 C 語言的程式，參與了很多專案，這六個月是
# antirez 職涯上很重要的轉淚點。
#
# ## 自創公司 Merzia
#
# 2000 年，antirez 加入了 Linuxcare 義大利分部，公司業務是開源軟體，他又在家
# 遠距工作，一切都很好——直到網路泡沫破滅。那一天公司發了一封郵件告訴員工：
# 「我們要關閉 18 個國家的業務，一個月後你們全部即將失業，晚安。」
#
# 2001 年，當時 23 歲的 antirez 有一個小孩，他需要養家活口。他開始寫一些 PHP
# ，包辦前後端，幫客戶做小專案。
#
# 2005 年是 Web 2.0 萌芽的年代，他跟朋友 Fabio Pitrola 開了一間叫 Merzia 的公
# 司，想在義大利市場做一些 Web 2.0 的應用。義大利電信（Telecom Italia）看到了
# 他們做的東西，寫了一封郵件，試圖建立合作關係。義大利電信後來買下他們做兩個
# 網站：一個是社交新聞網站 OKNOtizie，另一個是類似書籤網站 Delicious 的
# Segnalo。
#
# ## LLOOGG 與 Redis 的誕生
#
# 又過了幾年，antirez 和他朋友決定專注一個新領域：網站分析。他們想為部落客打
# 造一個工具，讓他們可以看到訪客的即時行為。例如：一個訪客從 Google 按進了這
# 篇文章，回到首頁，然後跳到某一頁。部落客可藉此改進網站的導覽設計。這個工具
# 名為 LLOOGG，當時的網站首頁上有幾句介紹，說明它與 Google Analytics 的不同之
# 處。
#
# LLOOGG 特別之處就在於它讓網站管理員監看某個訪客當下在網站上的活動，
# Google Analytics 一直到了 2011 才有這個功能，而 LLOOGG 創立在 2007 年，可見
# 之創新。
#
# LLOOGG 當時運作的樣子：https://www.youtube.com/watch?v=WsxRq8vgsBo剛開始 antirez 嘗試使用 MySQL，但馬上就發現性能問題。MySQL 每讀寫一筆資料，
# 都要動用到硬碟，資料量一多，運算全卡在硬碟的讀寫，網站就動彈不得。從現今眼
# 光來看，有經驗的後端工程師都會知道不應該選 MySQL 來實現即時應用，但在 2007
# 年這一切並不是這麼顯而易見。
#
# antirez 認為使用記憶體可以解決這個問題，於是他先用 Tcl 程式語言寫了一個記憶
# 體資料庫的原型（prototype），名叫 LMDB（LLOOGG Memory Database），這就是
# Redis 的前身。這個原型源碼只有 300 多行，但已足夠讓你一窺 Redis 的大致樣貌。
#
# 首先，這個原型已支援像是 SET、GET、LPUSH、RPUSH 等基本指令，你可以在上面使
# 用字串（string）與串列（list）兩種資料型別。此外，伺服器與客戶端的通訊協定
# 與 Redis v1 一致，設計上要讓人類可讀（human readable）且可快速解析（fast to
# parse）。
#
# Redis 預設的埠號 6379 也早已出現在 Tcl 源碼當中。九宮格鍵盤上 6379 對應到
# MERZ，由來是 Alessia Merz，一位義大利的模特兒。Alessia Merz 在電視上常說一
# 些不經大腦的話，逗樂 antirez 和他的朋友們，在朋友間他們會說「那個很 merz！
# 」來形容某個事物很蠢、沒意義。這個詞經過十幾年的轉變，merz 漸漸被他們用來形
# 容看起來很蠢，但卻有具有研究價值的東西，可看出他們的公司名字 Merzia 大概也
# 是這麼來的。
#
# Redis 的原型：https://gist.github.com/antirez/6ca04dd191bdb82aad9fb241013e88a8Tcl 源碼的前幾行，antirez 引用了一個套件卻沒使用，只留了一行註解
# # For [fork]。當時他想要利用 fork() 系統呼叫來實做永久儲存（persistence）
# ——把資料寫回硬碟的機制。這至今仍是 Redis RDB 的運作方式：利用 fork() 創造
# 出一個子行程，讓子行程去將資料寫到硬碟，父行程則繼續做原來該做的事。Tcl 源
# 碼沒有真的用到 fork()，antirez 只留了一行註解在那裡，因為當時他理解到 Tcl
# 已到了極限，是時候以 C 語言改寫了。
#
# 2009 年 2 月，antirez 的朋友 David Welton 幫他把 Redis 在 Hacker News 上公
# 諸於世——結果除了發文者之外，只有四個人回應他：三個人說已經其他類似的專案
# 了，只有一個人給予正面回覆，並提供幫助。這個人就是 Ezra Zygmuntowicz（不幸
# 在 2014 年去世 RIP），他當時在 Ruby on Rails 社群已相當著名，是 EngineYard
# 的共同創辦人。Ezra 為 Redis 寫了初版的 Ruby 客戶端 redis-rb，至今還是 Ruby
# 客戶端的首選，也成為 Redis 在 Ruby 社群流行起來的重要推手。
#
# 五年來，Redis 幫 LLOOGG 處理了二十億次瀏覽量。在 2014 年關站時，Redis 每秒
# 處理 350-400 個指令。而這整個系統僅是跑在一台每月 150 美金的虛擬機器上。
#
# ## GitHub, Instagram, Twitter 加入行列
#
# 儘管 Hacker News 上沒有獲得熱烈回響，antirez 每天仍利用工作之餘開發 Redis，
# 大概持續了一年，慢慢開始吸引用戶。
#
# 當時他手上還有兩個開源專案：hping 和 Jim Interpreter，但 Redis 是第一個讓他
# 覺得可以長期投資的專案。他對資安失去興趣後，就停止開發 hping；他對 Tcl 的走
# 向失望，投入 Ruby 的懷抱後，就停止開發 Jim Interpreter。但他很肯定他離不開
# 資料庫，所以 antirez 就假設 Redis 會成功，繼續開發，因為就算不成功，至少他
# 自己在往後幾年都會繼續使用這個資料庫。
#
# 2009 年，與 Redis 發佈同年，一間叫 GitHub 新創公司的 CEO，Chris Wanstrath
# 利用 Redis 寫了一個工作隊列系統 Resque，用來跑 GitHub 的背景任務。在 Rails
# 的世界，Resque 是當時最熱門的工作隊列系統。2012 年出現的一個後起之秀
# Sidekiq，也是建立在 Redis 的基礎上，是現在 Rails 工程師的首選。
#
# 另一間新創公司 Instagram，其中一個創辦人 Mike Krieger 在 2010 年開始與
# antirez 通信，討論該怎麼利用 Redis 打造 Instagram。當時 Instagram 和 Redis
# 都是剛起步，Mike 和 antirez 也互不相識。因為 Instagram 在最初幾年是完全建造
# 在 Redis 之上的，所以如果沒有 Redis，很可能就不會有 Instagram，或至少會晚點
# 才問市。
#
# 2010 年，Twitter 也加入 Redis 的行列。Twitter 最重要的功能「時間軸」，背後
# 便是使用 Redis。有趣的是，antirez 在 Redis 剛發表完沒多久（2009 年 3 月），
# 就寫了一個簡單版的 Twitter 叫 Retwis，以展示如何使用 Redis。
#
# ## VMware 和 Redis Labs 的資助
#
# 至此，Redis 專案對 antirez 來說還只是一個嗜好。大概持續了一年，他無償的改進
# Redis 並釋出新版，直到有一天，VMware 打電話過來。
#
# 「我們想付錢贊助 Redis，VMware 在義大利有分部，我們想騁請你，你想成為我們的
# 員工嗎？」antirez 問：「那我需要為你們做什麼？」「不不不，你只要繼續做你現在
# 做的事，我們就會付你錢。你只需要在網站上寫 Redis 是由 VMware 贊助的即可。」
#
# 就這樣，Redis 有了一個金主，antirez 和 VMware 合作開發 Redis 好幾年。VMware
# 後來與 Pivotal 分拆，antirez 又轉到了 Pivotal。
#
# 隨著用戶愈來愈多，市場上出現了第一批提供 Redis 顧問服務的公司，其中有一間來
# 自以色列特拉維夫的公司叫 Redis Labs。它本來的名字叫 Garantia Data，一開始是
# 資料庫供應商，後來公司改名為 Redis Labs，轉型專注做 Redis 相關的業務。
#
# Pivotal 和 Redis Labs 有一個共同投資人，某一天他告訴 antirez：「你在 VMware
# 幹嘛？去 Redis Labs 吧，那裡才是你產品的支援中心。」於是 antirez 轉到了
# Redis Labs，並在那邊工作至今。2021 年 8 月，Redis Labs 更正式改名為 Redis，
# 原本是專案網站的 redis.io 變成了公司網站。
#
# ## 十年後
#
# Redis 誕生後十年，2020 年 1 月，antirez 在 Redis Day 會議的講台上，用他招牌
# 的義大利腔英文介紹 Redis 6.0 的新功能。在 Twitter 上還可以找到一些與會人員
# 和 antirez 的合照。
#
# 回顧 Redis 這十年來的成長：
#
# 時間           版本    新功能
# 2009 年 2 月   ?       字串、串列
# 2009 年 9 月   1.0     集合、有序集合（sorted set）、永久儲存（RDB, AOF）等
# 2010 年 9 月   2.0     雜湊、發佈訂閱（pub/sub）、Lua 腳本、HyperLogLog 等
# 2015 年 4 月   3.0     叢集（cluster）、地理資料型態
# 2017 年 7 月   4.0     模組（modules）：RediSearch、RedisJSON、RedisGraph 等
# 2018 年 10 月  5.0     串流（stream）
# 2020 年 1 月   6.0     SSL、存取控制（ACL）等
#
# 同年 6 月，antirez 在部落格寫了一篇文章告訴大家，他決定退出 Redis 專案的開
# 發及維護工作。他仍然會在 Redis Labs 擔任顧問的角色，提供意見，但不直接參與
# 開發。十年多來奉獻在同一個專案上，讓 antirez 倦怠了。
#
# 對 antirez 來說，寫程式是一種表達自我的方式，是一種藝術。每一個字元、斷行都
# 要精雕細琢，彷彿是另外一種藝術形式——寫作。軟體開發就像是在寫一本書，它必
# 須美觀、優雅、容易理解。如果這個軟體剛好是對其他人也實用，那也只是副作用罷
# 了。
#
# 當然，antirez 也理解這個想法不切實際。當你的軟體被大規模採用，你就必須做出
# 許多妥協，讓你的軟體變得不那麼完美，但卻對大部分人實用。維護 Redis 變得愈來
# 愈具挑戰性，讓他在藝術和實用性之間陷入掙扎。這使得 antirez 感到疲憊與壓力，
# 開始渴望回歸那個藝術家的身份，去創作更純粹的程式藝術。
#
# 離開 Redis 專案後，antirez 寫了一本關於人工智慧的科幻小說《Wohpe》，於 2022
# 年 7 月出版。同年 4 月，Redis 團隊發佈了新版本 7.0，這是 antirez 退出專案後
# 的第一個重大版本。
#
# --antirez 本人在 Hacker News 回應了這篇文章 :https://news.ycombinator.com/item?id=35871462#35893871原文中有兩個錯誤已更正：
# 1. 在米蘭 antirez 沒有被解雇，他是自己離開的
# 2. 他的第一台電腦是 TI-99/4
# ====================================================================================================
# 第 9 篇:
# 對岸的詞語 卷 好像就是一個很競爭的意思
#
# 我發現好像台灣這邊的前端也差不多
#
# 個人經驗不足  只是剛學HTML而已  對於這樣的現況很好奇
#
# 怎麼前端會走到這樣子的地步
#
# 是有什麼歷史 讓大家都跑來前端嗎  甚至還有一個前端難民的說法
#
#
# 有沒有資深前輩願意分享台灣前端環境的歷史
#
# 我自己是猜因為某些培訓機構宣稱這條路很好走啦(?
#
# 不過應該還有其他因子
#
# 各位怎麼看？
#
#
# 想聽各位討論看看　來聊聊台灣前端卷什麼意思的吧！
#
# --
# ====================================================================================================
# 第 10 篇:
# 各位好，之前曾經問過offer選擇的事情，很感謝版友們給我的回饋
# 目前在猶豫是否應該在目前的工作轉正(前端)
# 或是去AppWork School上課(資料工程師)
# ----
# 本身是統計系，畢業兩年了，今年初自學前端，
# 三月有幸得到工程師助理約聘的機會，
# 目前做了一個多月，主管覺得可以轉正職
#
# 其實可以轉正這件事完全沒想到，
# 原本計畫是三個月好好精實能力，
# 跟了解職場工作方式後就去上課，
# 但現在突然有能夠正職上班的工作機會，
# 不太確定該如何評估
#
#
# 而大學時統計部分比較偏向數統證明，
# 爬蟲採礦就是課程時跟專題有用過而已，
# 目前前端部分應該算是相性蠻好，
# 目前已幫公司完成兩個系統的前端內容，
# 跟後端溝通也沒甚麼問題。
# 目前評估是對兩個領域都不排斥
#
# 猶豫的點是雖然是正職，
# 但也知道前端的薪水跟競爭者都蠻多的，
# 在今年有報名AppWork School的課程，
# 雖然還沒有放榜(19號放榜)，
# 但還是想先詢問各位版友的建議，
# 多點時間思考各種情況下該怎麼做比較好
#
#
# 想請問
# 1.以資料工程師的工作內容來說是否在台灣會比較好找到工作機會跟更好的前景呢?
# 2.若以之後想要尋找較穩定的工作，如銀行或是中華電的話，應該要累積當下工作年資好
# 或是把握能學習新技能(資料工程師)比較好呢?
#
# （夢想是五年內能找到平均6-7萬月薪的工作穩穩做到老就好）
#
# 再麻煩各位的指點了，謝謝各位耐心看完！
#
# --謝謝上面各位版友的建議，目前有在休息跟下班時間學習後端跟AWS的東西，也覺得自己
# 有餘力會想要練後端的部分
# 但想請問上面的版友都是建議轉正職嗎？有在考慮的就是起薪
# 畢竟appwork撐完四個月的起薪是很不錯的
# 比起直接轉正
# 再來就是如果轉正了沒幾天就說要離職
# 感覺實在不是很好...
# ====================================================================================================
# 第 11 篇:
# 我是覺得因為寫web(web前後端)程式比電機的簡單，容易入門，薪水隨便就3萬以上，學
# 習資源也很多，不像設計電路跟寫韌體，師父要帶入門，一般人根本難以進入，寫web就
# 是阿貓阿狗就可以進入
# 執行緒好容易學一學，lambda好簡單，anotation真容易，23種設計模式也超級簡單，也
# 就吸引一狗票人進入資訊業了，每個都會看原碼。
#
# 但很少人去學設計電路去寫韌體
# 像電機系門檻真的很高，設計電路ic，拉電路板layout，寫verilog，大部分都在搞bit 1
# 100 0011
# 接下來另一種就是寫韌體，這種門檻也很高，要了解計算機組織，了解linux kernel的co
# de。
#
# web跟手機應用才適合一般普羅大眾，根本沒有門檻
#
#
# --
# ====================================================================================================
# 第 12 篇:
# 身為設計模式哥,我真的覺得設計模式也蠻easy的
# 不過大部分人的話可能卡在學習這一關
# 可能看書學,看一看覺得太抽象就放棄了
# 通常業界會看設計模式都是主管級的
# 應該是能力比較好(讀書能力比較好,記憶能力比較好)的這種
# 不過這種也是把code背起來,看到一樣的情境就套用
# 其實跟實際上做工的工程師能靈活運用還差一個坎
# 之前就看過鄉民留言說,有人套了設計模式以後就改不動
# 就是這個緣故,小魯設計模式也有一年半到兩年的時間了
# 業界主管級會設計模式的說真的八成都是拿來嘴的
# 不過原po太高估業界的工程師了,或是不了解業界情況
# 年輕的工程師下班或假日可能回到家還要打電動追劇
# 沒人那麼上心還學設計模式拉
# 而且我都待小公司的,正常狀況十家公司裡沒一家用設計模式的
# 就算會用也是就像數學套公式解題的拉~
#
# --
# ====================================================================================================
# 第 13 篇:
# 各位年薪300萬大大好，小弟我國立科大資工學士畢，相關工作經歷5年，有幸獲得兩個
# offer，想請各位先進給點建議：
#
# N為現職月薪。
#
# [現職]
# 新創博弈
# 職位：工程師
# 工作內容：開發後台系統、App
# 工作地點：台南
# 薪資：N*13+三節
# 工時：幾乎不加班
# 住所：家裡
# 備註：純開發不做維運，目前不會被OnCall，事情以博奕來說偏少，整體上來說還蠻涼的。
# 不過接觸的技術蠻雜的，有碰C#、Vue.js也有碰Flutter，且之前還有別間接案公司做不
# 完的項目（非博弈相關）丟給我們做，有點傻眼。
# 有聽到之後可能會接維運。
#
# [選項1]
# 小星星
# 職位：軟體開發工程師
# 工作內容：內部系統開發(C#)
# 工作地點：新北中和
# 薪資：(N+5k)*(16~18)
# 工時：面試是說幾乎不加班
# 住所：公司提供宿舍/租屋
# 備註：月薪跟期望月薪的差距有點大...（雖然爬文後已經有心理準備就是）
#
# [選項2]
# 紅花
# 職位：軟體開發工程師
# 工作內容：ASP.NET MVC 開發
# 工作地點：新北板橋
# 新資：(N+10k)*14
# 工時：偶爾加班
# 住所：租屋
#
# 研華的話還在等待中，如果有研華的話會比較好嗎？或是繼續找？
#
# 先謝謝各位大大們解惑
#
# --我第一份工作也在台南，現在回來看當時是真的蠻低的，且從進去到離職調薪可以說是幾乎沒有。謝謝M大的建議，確實人資有詢問時我都會據實回答，只能說我太天真了QQ謝謝各位的答覆，小弟我大概有個底了。N的部分已隱藏。
# ====================================================================================================
# 第 14 篇:
# 徵才文請依照以下格式填寫
#
# ****特別注意!****
#
# 有補休不等於符合勞基法
# 員工可請領加班費與或自願補休才符合勞基法
#
# "資料填寫不確實"將刪文處理
# 資料無法填寫請站內信版主處理
#
# 若填寫的資料有不實，公司將可能觸及
# 偽造文書(公訴罪)
# 勞動基準法(行政處罰)
# 民法侵權(民事賠償)行為等條例。
#
# 徵人公司與徵人主管與PO文者將負擔相關刑事責任
# 本板將全力配合檢方調查相關公司不法事證並必要時出庭作證!
#
# 以上閱讀完畢請刪除(游標移至最上方按下CTRL+Y)
#
#
# 公司名稱，統編(中華民國以外註冊可免填):
# 中央研究院 南部生物技術中心  林哲揚老師實驗室
#
# 公司地址(填寫詳細至號):
# 711010台南市歸仁區歸仁十三路一段100號
# （近台南高鐵站之中研院南部院區新大樓）
#
# 職缺: 生物資訊專員兩位
#
# (多職缺可自行增加填寫)
#
# 職缺能力經歷要求:
# - 必備技能：具程式撰寫能力 (例如：Python/ Perl/ R 或其它……任一種即可)。
# - 加分技能：有分析NGS定序資料經驗
# - 學歷要求：已取得(或即將取得)碩士學位或博士學位
#
# 員工是否需自備工具? (是/否) : 否
#
#
# 薪資(月薪):
# 碩士：月薪 NTD 45,000 起
# 依經驗、能力、表現與預期成果調整，於起聘前討論
#
# 薪資(保證最低年薪，必填項目): 12 個月
# 碩士：月薪 NTD 45,000 起
# 依經驗、能力、表現與預期成果調整，於起聘前討論
#
# 年終獎金計算方式:底薪計算/全薪計算
# 1.5 個月
#
# ****以下工時與加班費必填，不填刪文水桶****
# 工時:
# 每日工作時間: 09: 00AM-18: 00PM 午休1小時（可彈性調整）
# 中午休息 (12:00~1:00)
# 每周工作時間: 8*5=40
#
#
# (需符合國訂勞動基準法)
# 勞工正常工作時間，每日不得超過八小時，每週不得超過四十小時。
# 前項正常工作時間，雇主經工會同意，如事業單位無工會者，經勞資會議
# 同意後，得將其二週內二日之正常工作時數，分配於其他工作日。其分配
# 於其他工作日之時數，每日不得超過二小時。但每週工作總時數不得超過
# 四十小時。
#
#
# (補休不算符合勞動基準法，需有加班費，否則仍算是違法）
# (須符合國訂勞動基準法)
# **無須加班仍須填寫加班費制度**
# **可直接填寫加班費比照勞基法，低於勞基法禁止發文**
#
# 加班費制度：
# 依國訂勞動基準法規定
#
# 如雇主有使勞工每日工作時間超過8小時者，或單週超過40小時者，應依法給付加班
# 費，其標準為：（勞動基準法第24條）
# （1）延長工作時間在2小時以內者，按平日每小時工資額加給3分之1以上。
# （2）再延長工作時間在2小時以內者，按平日每小時工資額加給3分之2以上。
#
# 補休使用需員工同意，經錄取員工檢舉無加班費，一律轉發勞動部進行勞動檢查。
#
#
# 工作環境與該職缺團隊介紹:
# Our lab applies NGS (Next Generation Sequencing) high throughput sequencing technology to generate big data to study DNA methylation, histone modification and gene expression。我們需要不同領域的人才一起合作，包含資訊、統計、數學及生物相關專長。歡迎有生物資訊學相關知識或實作經驗的新成員加入團隊。
#
# 工作福利:
# 1.年終獎金
# 2.依規定享有院內設施相關優惠
#
# 公司分紅與獎金:
# 年終獎金
#
# 公司介紹:
# 中央研究院
#
# 人資或徵才聯絡方式:
# 1. 在電郵標題中載明：應徵生物資訊研究工作- XXX (XXX 為應徵者的名字)
# 2. 在電郵主體中載明：請簡述加入實驗室之動機及目標; 可開始工作日期; 指導教授絡電郵與電話
# 3. 在電郵附件中：附上履歷與論文摘要之電子檔
# 4. 以Email寄給林哲揚老師 jeryoung{at}sinica.edu.tw，{at} 請置換為 @
#
# --
# Sent from nPTT on my iPhone 14
#
# --
# ====================================================================================================
# 第 15 篇:
# 誒不是, 內捲的定義是什麼都沒搞清楚大家還可以討論得這麼開心 ==?
# 內捲是 involution 的中國翻譯
#
# 太學術的東西就先不談了, 白話一點的講
# 內捲化最大的特徵是「投入資源但是卻沒有任何實質的成長」
# 下面有個簡單的例子:
#
# 內捲就是看電影的時候, 前排的人看不到螢幕, 於是站起來看, 擋到了後面的人, 後面的
# 人只好也跟著站起來, 最後導致大家全體起立看電影, 沒有人獲得額外的福利, 但是大家
# 都更辛苦了, 最後獲得的結果和坐著是一模一樣的: 看電影。
#
#
# 為什麼一堆人對軟體工作趨之若鶩, 為什麼市面上一堆程式補習班?
# 第一是進入門檻相對低(後端 crud 會寫, 前端做得出畫面就有入門工作了)
# 第二就是因為這行業投入跟回報是成正比的啊
# 縱使有生存者偏差的問題, 但不可否認
# 從外行人轉職, 拼個兩三年年薪百萬的大有人在
# 這樣是捲在哪裡我實在看不懂
#
# 如果今天台灣只剩下半導體公司有開軟韌體職缺
# 然後非四大純血碩面試上的機率只有 0.01%
# 剩下的資工系畢業全部賣雞排
# 這才有資格喊內捲吧
#
# --║╠╣╠═╗      ║║◥█◤╠╣╠╝      ║--蛤? 你領 40k 租 40k 的房子是我的問題嗎
# ====================================================================================================
# 第 16 篇:
# 今年由於是轉職第一年，年薪只有大概在60-65左右(很慘我知道)，老實說這樣的薪水，
# 北漂真的壓力不小，如果目標以兩年內(30歲)達到百萬的程度，不曉得走哪條路比較有機
# 會，想再拚個兩年，真的不行就要滾回中南部了QQ。
#
# 一、    背景介紹
# 現年28歲商學院畢業，工作即將滿5年，過去都是在傳產/科技業的領域發展，做過工具機
# 廠-生管、航太製造-PM、外商設備商-Planner 。
#
#
# 二、現職工作
# 在設備商工作學了一些VBA，開始對Coding產生一些興趣，因此轉到四大當顧問(也就是乙
# 方公司)，在金融業開發流程機器人RPA，主要會用到技能是RPA、Python、VBA、MySQL，
# 除了開發以外，也需要跟客戶開會談需求、寫開發文件例如系統規格書、梳理業務流程產
# 出畫流程圖，因為基本上都是一人專案，所以都是一條龍自幹。
#
#
# 三、未來方向及問題
# 1.      自認Coding技巧不到最頂尖，沒能力成為一位技術大神，自己還是比較喜歡與人
# 互
# 多一點，需要大量溝通的角色，也是我當初一直想走PM的緣故，但又不希望當個完全不懂
# 程式的PM。
# 2.      職務部分：想要請教看看未來的方向，以與人多互動溝通為主的話。
# 1)      依這樣經歷應徵PM或SA有機會嗎?
# 2)      不知道這些開發經驗能否應用到其他軟體產品之上?  還是這些經驗完全無路用
# ？
# 3.      產業部分：未來目標是跳到甲方公司的話，比較偏向可以在金融/科技製造業，
# 自己想法是因為待過製造業，對於製造業的業務流程很熟悉，也許有一些數位轉型的Team
# 有機會進去，是不知道這個想法有沒有問題，而金融業的話也有客戶問我要不要過去，不
# 過是純開發的職務內容，個人興趣度普普。
#
#
# 因為思緒有點亂，打得亂糟糟，因為看到同儕發展的都不錯，自己北漂存不太到錢又接近
# 30的狀況下，實在是心裡非常慌跟沒有頭緒。
#
# 今年整個景氣大環境不佳，科技業都在裁員，一度思考到是否要去應徵外派東南亞的傳產
# 去賺快錢了，希望有前輩能給點建議，謝謝。
#
# --同學前端兩年半破百現在半導體業逆風 可能要等等了D大說的是 會在多思考的 謝謝我以為很差 謝謝金融業環境確實比較封閉05/12 10:52
# 感謝F大分析感謝B大建議感謝S大建議，會考慮看看這條路，謝謝。
# ====================================================================================================
# 第 17 篇:
# # 前言
#
# 背景：
# * 113 CS 學士 + 112 CS 碩一
# * Leetcode 近半年內 ~200題 medium + ~100題 hard
# * 大學時拿過幾次書卷獎，2篇一作 + 1篇二作 （極冷門領域 top conference）
# * 必修 GPA 4.3/4.3，選修課大部分為 AI、演算法（圖論）、多媒體相關
# * 沒競賽、沒實習經驗、沒朋友內推
#
# 從高中打電動、選校系，到研究所推甄、選教授都收到 PTT 很大的幫助，
# 因為板上看起來八成的心得都是電神在發，想說發個反面教材給大家參考，
# 希望會對你/妳有幫助！
#
# 今年投遞的大部分都是 AI research/軟體缺，
# 因為對硬體極度過敏所以連修課都沒修，也不投遞硬體相關職缺
#
# 懶人包：
# 拿到 offer：無
# 進入面試後被刷：AICS, MTK, HPE
# 連面試都沒進就被刷：
#         Google, Amazon, Yahoo, Microsoft TW, MSRA, Synology,
#         Intel, Synopsys, Kronos, Dcard
#
# 結果 Leetcode 刷這麼多題，根本沒有用到...
#
# # 面試分享
# 本來想要分享面試過程的，但是沒什麼好分享，不過還是把投遞時程分享給大家
#
# ## Google - Software Engineering Intern
# * 10月底投遞 、2月底感謝信
#
# ## Amazon - Software Development Engineer Intern, IOT Lab
# * 11月中投遞、12月底HR通知職位停招
#
# 超級超級傻眼的一家公司，校招辦的糟糕到讓人嚇到，很難相信這是 Amazon，
# 裡面介紹的 N 個職缺居然只剩下 Cloud Support 有在招募
#
# ## Microsoft TW - RD Intern
# * 4月初投遞，至今沒消息
#
# ## AICS - Research Engineer Intern
# * 11月中投遞、7天內收到 codility OA 並完成
# * 11月底收到面試邀請、12月初面試
#
# 面試官是一位話不多的工程師，先自我介紹 1 分鐘後出了一題 hard，語言不限
# 比較特別的是面試官在一開始就把題目的要求講的非常清楚
# （整數範圍、array 大小、甚至給了幾個 example，都在我沒問的情況下講完了）
#
# 先簡單分享一下想法後，寫出暴力解拖延一下時間，之後寫出次優解，
# 過程中面試官會很認真的看著鏡頭然後用 "嗯" 來回應，不會有任何問題，
# 卡了大約 10 min 後面試官直接跟我解釋答案QQ，
# 然後很語重心長的跟我刷題很重要，雖然工作用不太到
#
# * 面試後 5 天收到感謝信
#
# ## Yahoo - Research Engineering Intern + Software Engineering Intern
# HR 有特別提到可以同時申請多個職位，
# 會先面試志願序高的，被刷掉後面試下一個職缺
#
# * 12月底投遞
# * 4月中收到後者的感謝信，追問前者進度
# * 隔天收到前者的感謝信
#
# Yahoo 是我心目中的第一志願，所以蠻傷心的
#
# ## Synology - Cloud Product Developer
# * 3月底投遞，至今沒消息
#
# ## MTK - 影像演算法 + AI&Computing Platform
# * 3月初投遞
# * 4月初收到面試邀請 + C語言 OA （面試前完成即可）
# * 4月底進行面試
#
# 相信 MTK 的面試過程在網路上可以找到非常多參考，這邊就不贅述，基本上就是聊天，
# 比較特別的是 C語言 OA 裡面有考 C++，還算簡單不過殺我一個措手不及，
# 不過面試當天有 7~8 位主管進來，有點嚇到，面試時間 2.5hr 也是我面過最長的
#
# * 至今沒消息，同學都在面試完一週內收到 offer，應該沒戲了
#
# ## Intel - Datacenter Software Engineer Intern
# * 4月底、開放職缺當天投遞，至今沒消息
#
# 一直沒收到面試心態有點崩，所以投了感覺會比較少人投的職缺，
# 結果還是沒有面試
#
# ## Synopsys - AI ML Intern
# * 3月中投遞，5月中收到感謝信
#
# ## HPE - Software Engineer Intern
# * 4月中投遞
# * 馬上收到電話，約定隔天面試
#
# 需要準備 5 分鐘英文自我介紹，之後簡單問一下履歷，
# 簡單介紹了一下工作內容，是需要將工廠內的人工 testing 寫 script 自動化，
# 之後考了一題 leetcode easy (使用 python)
#
# * 至今沒消息
#
# ## Kronos - Summer Intern
# * 3月中投遞，一周後收到 OA
# * OA 包含了選擇題考題 + 幾題 leetcode medium（語言只能使用 C++）
# 平常刷題都是用 Python 刷，所以複習了 C++ 一下就去寫，
# 前面的選擇題蠻難的，不過平常有準備到所以還好，
# 不過很久沒碰 C++ 狀況很差，感覺沒有一題會 AC，被刷不意外
#
# ## Dcard - ML Intern
# * 2月初投遞
# * 3月底收到作業
#
# 作業是類似 kaggle 競賽的東西，時間應該是大家統一的，
# 用蠻特別的方法 train 了幾發後寫個報告就交了
#
# * 4月底收到感謝信
#
# 叫人寫作業又不給 feedback 讓人感覺很差
#
# # 結語
#
# 沒實習經驗，也沒做什麼 side project 應該是最傷的部分，
# 我有的技能和大部分的 JD 都不太符合
#
# 如果再給我一次機會，我一定會把大二的我打一頓之後去修硬體課，
# 看看 Google Hardware intern, Silicon Intern 都快上工了還沒收滿
#
# --幫你QQ 好多人都 team match 沒過其實我主要是想去 SWE/SDE Intern 無奈幾乎沒有什麼缺QQ我不認爲不喜歡某個領域，就是性格缺陷
# 也不認爲無條件的配合長官會是性格優勢，頂多只是 Culture 不同罷了講完他也露出一絲神祕的微笑...補充說明一下：我在面試的過程中完全沒提到類似的事情，
# 我會針對JD整理出一下有興趣的部分做一些功課才去面試大部分學校必修課還是用 C/C++，不過Python刷起來比較快，
# 去外商上班的學長姐回來也有分享過內部用的Library跟外面寫的有很大差別，
# 都需要重新學，所以就不打算用 C++ 刷題了他很認真，其他面試官不是不開鏡頭就是眼神飄忽，應該只是話不多吧我覺得檢討「面試有沒有失誤」比較重要。
# 面試沒過的原因有千百種，如果一昧的檢討自己，應該很快就憂鬱症了我想我可能沒有講的很清楚，讓人誤會
# 我覺得「面試有沒有失誤」和「面試有沒有過」是不完全相同的事情
# 如果面試的很好，不過因爲種種原因（HC被收回、別的candidate就是超強）而沒通過，
# 這樣的情況應該不是自己短時間就能改變的，所以我認爲沒什麼好檢討的；
# 如果面試的不好，但是就是缺人所以抓你上工，難道不需要檢討嗎？
# 不過我也沒有看懂你推文的意思就是了
# ====================================================================================================
# 第 19 篇:
# 請大家多多傳唱，支持IT平權 哈～
# 網頁版（包含歌詞解析）：https://vocus.cc/article/645eaafffd89780001b77802在小小的公司裡 加班加啊加
# 談什麼樣的需求做出什麼樣的渣
#
# 在大大的程式裡 抓呀抓呀抓
# 藏大大的bug 讓IT被打趴
#
# 在特別大的CR裡 加啊加啊加
# 用特別少的時間 要品質怎麼佳
#
# （間奏）聽媽媽的話 別讓他受傷 想快快長大
#        才能保護他...
#
# --
# ====================================================================================================
# 第 20 篇:
# 小弟四大資工學士畢業，工作經驗約四年，之前都是在台灣公司。
# 目前待業中，想找台北的外商工作機會，但可能是經濟不景氣，覺得外商的職缺好少，主動投履歷都沒消息。
#
# 最近想說先用104找個工作當過渡，至少有薪水收入，等景氣回來再尋找外商機會。
# 不過目前面試運氣也不佳，明明面試覺得算順利，面試官也會超時繼續跟我聊，但都收到感謝函。
#
# 現在有收到一個派遣外商的offer，薪水也能接受。雖然好像大家都不推派遣，但如果是當過渡期工作，去體驗認識一下外商的工作環境跟模式，是不是也沒到那麼差？
#
# 版上好像很少這種派遣外商的討論分享，希望大家提供小弟ㄧ些建議。
#
# -----
# Sent from JPTT on my Realme RMX3371.
#
# --
# ====================================================================================================
# 第 21 篇:
# 看到下面有篇大神有討論到這次 Dcard ML 實習作業，因為沒有收到團隊的具體反饋
#
# 想和大家討論作業的狀況
#
# 題目是用結構資料，包含標題、看板資訊以及1-6小時的愛心數和評論數等等
#
# 來預測發文後 24 小時的愛心數
#
# 因為當時是期中，我只大概花了五天約二十個小時來做
#
# 我的作法大致如下
#
#
# 首先先用 XGBoost LightGBM 把量化資料做出 baseline
#
# 但沒辦法處理最重要的標題資訊
#
# 所以就直接拿 Huggingface BERT 來做
#
# 直接把資料餵進去的訓練是無法收斂的
#
# 後來也嘗試一些 Emsemble 和 training tricks
#
# 但也都沒辦法收斂，甚至達不到 baseline 的效果
#
# 認為是資料量的問題
#
# 到這邊沒什麼特別想法就直接寫報告了
#
#
#
# 我一直都主要是做 CV ，碩論跑去做 3D
#
# 對 NLP 非常不熟悉，不知道是否有漏掉關鍵操作
#
# 想請同有拿到作業的大神指點
#
# 謝謝
#
#
# --任務如文中所述，是迴歸問題，目標是文章發文後24小時的愛心數
#         因為有中文標題，故直覺想到就是 BERT，將中文標題 tokenize 後
#         連同其他 feature 一同 concatenate，送入BERT直接 end2end 訓練出愛心數不知道實驗室內有沒有其他效果比較好的解法？謝謝提供思路，但LSTM的話要如何考慮中文標題？
#         一樣使用word2vec或tokenizer嗎？謝謝，確實我幾乎沒有做 feature engineering
#         是否方便請教後續是用什麼方法回歸出愛心數？謝謝DrTech大的回復，tokenizer出來的embeddings我是有再downsampling的
#         當時也有考慮到這件事情，我也測試過downsample到4 - 16或其他一些奇淫巧技
#         也有對tokenizer做regularization等等，但對訓練幫助都不大
#         至於標題是否影響愛心數，確實實際上不一定
#         但該資料集提供的特徵數很少，其餘大多都是scalar
#         相信他們一定希望受試者去分析標題，當然處理整個標題可能不是個好辦法
#         1-6小時愛心數與24小時愛心數的相關性非常高
#         故我也在BERT之中嘗試建立使用這些高相關feature的MLP迴歸模型
#         以及和 XGBoost LightGBM 的 Ensemble
#         但對訓練並無明顯益處
#
#         我在寫這份測驗的時候，並不覺得量化結果會多好，因為僅有約五萬筆資料(文章)
#         而同時也要展現工程能力，譬如我用 Pytorch-lightning 架構整個
#         training, monitoring, evaluation pipeline
#         實作上的能力可能會區分我與其他一部分的面試者
#         但結果看來可能是有大神直接幹出很好的模型和訓練結果
#         後續評分項如解題思路、報告呈現和實作能力都沒有被考量了
#         才很好奇進入面試的大神是怎麼得出很好的預測方法的
#         感謝您的回覆
# ====================================================================================================
# 第 22 篇:
# 看到版上蠻多篇分享實習面試的心得文章，就想說也來分享一下我自己的好了
#
# 因為我對寫iOS APP的興趣比較多，鑽研也比較深，所以暑期實習就只有找有開Mobile App 實習的職缺，找來找去好像只有Yahoo
#
# 我申請的職位是Mobile App Development Intern，來跟大家分享一下我經驗
#
# 我是完全主力攻iOS App的，完全沒碰過Android
#
# 學歷：在加州讀社區大學一年，後來疫情回台灣，轉入逢甲大學資工系，目前大三
#
# 獎項：蘋果移動應用創新賽三獎（中華區）、聯發科智在家鄉淺力獎    等，有一些小獎不值得一提的就不列上來了
#
# 社團：大二擔任iOS Club教學長、大三擔任iOS Club技術長（https://iosclub.tw）
#
# APP：App Store上架過三款APP（其中一個APP使用人數超過四萬）
#
# 志工：擔任葳格高中程式營隊助教、大學助教  等，因為一頁式履歷放不下就沒列出來了
#
# ——
# 接下來是面試的部分，面試總共有三關
#
# 投履歷：2/12
# 一面：2/20
# 二面：3/3
# 三面：3/10
# 時間都很自由，我都是挑我學校沒有課的時間面試
#
# 第一關：先跟Hiring Manager 做線上面試，內容大概就聊一下我的履歷跟過往的經驗，然後考了一題hash table資料結構跟一題leetcode easy演算法。時間約一小時左右
#
# 第二關：這關總共三個人一起面我，Hiring Manager 及Yahoo的兩位資深iOS工程師。考了一題演算法、一題物件導向相關。然後就跟兩位資深iOS工程師聊一下比賽作品、社團經驗、跟上架經驗以及如何實作功能的內容。過程約兩小時左右
#
# 第三關：跟HR聊聊天，聊一下進去之後主要會負責什麼工作、公司文化、薪水  等等相關的介紹，還有一些behavioral問題。約半小時左右
#
# 口頭Offer：3/13
# 紙本Offer：3/17
# HR說要送美國給總公司審，所以final offer approval 是3/17，總算拿到真正的offer letter
#
# 老實說我覺得自己蠻菜的，校名普普，然後自認演算法（數理邏輯）很爛，LeetCode也沒什麼刷，大一的時候因為上程式設計用C語言寫了Easy 10-20題而已吧，後面完全沒碰過了，當然面試前有去惡補一下資料結構跟常見的演算法，但自認還是很菜。非常感謝這次的幾位面試官，我收穫滿滿。
#
# 如果有人也申請了今年暑期的Intern，可以一起討論下～
# -----
# Sent from JPTT on my iPhone
#
# --
# ====================================================================================================
# 第 23 篇:
# 幣託技術總監 aka BigO因為當管理忘記的總監
#
# 前陣子發生解題影片事件後
#
# 聲稱要暫停目前的更新
#
# 結果今天一個忍不住又出來為軟體工程界主持公道啦
#
# 事由：有人問他想要賺錢且想往軟體工作發展
#
# 他自己的看法
#
# 畢竟他身為一個虛擬貨幣技術總監
#
# 由他來代替大家回答再適合不過了！https://i.imgur.com/FMQ5PuJ.jpghttps://i.imgur.com/Q7NvOnL.jpghttps://i.imgur.com/IFwEoVO.jpghttps://i.imgur.com/yORpugM.jpghttps://i.imgur.com/iFVGnWH.jpg大家不曉得對於這位技術總監的多年經驗心得有什麼看法？
#
# --
# ====================================================================================================
# 第 24 篇:
# 工作這幾年來基本上都待在配備超爛椅子的地方
#
# 每當腰酸背痛的時候，我就會思考是不是應該買張好椅子進公司
#
# 但只要想到連老闆都沒坐那麼好的椅子的時候
#
# 就又會顧慮到很多人情世事，或怕造成其他麻煩
#
# 尤其公司還很驕傲的申明過有幫員工挑過椅子...
#
# 然而，最近深深體會到背真的快斷掉了...
#
# 所以目前有一些想法：
#
# 1. 買個不用太頂的椅子頂一下，緩解不適感過一天算一天
#
# 2. 買來放家裡，雖然利用率沒在公司高，但舒緩一小時算一小時
#
# 但這都是權宜之計，因此來求助各位大大是否相關經驗可以分享？
#
# --
# ====================================================================================================
# 第 25 篇:
# 本板規部分沿用前版主TONYQ板規，生效日2016年1月1日----精神:極簡
# 舊板規文章代碼:#1DaVkv8L徵才板規:
#
#  A-0:徵才文禁止刪除，因PTT為免費平台，非付費徵才平台，留存相關資訊為重點，
#      禁止po文後刪文，若有發現自行刪文或來信要求刪文一律不處理，徵才時視同
#      已了解該規範，若堅持刪文者 紀錄帳號與公司在案並永久水桶後方可刪除。
#
#
# 【A】:[徵才] 文章不禁止，但有以下限制：
#
# a. 徵才、工作內容需與資訊或軟體工作內容相關。
#
# b. 同一公司發表之相同徵才文，間隔需超過五天。
#   （多職缺可分開，不可超過三）
#    (超過三種不同職缺，請間隔三天再發文)
#    (不符規定被刪文後，重新PO不再此限)
#
# 【B】: 標題規範:
#
# [徵才] PTT論壇徵JAVA程式設計師(65k~100K/5Y)
#
# 請以簡略薪資快速說明職缺"薪資"與"資歷"要求，方便與查詢。
#
# 【C】: 內容規範:
#
# 請使用徵才範本，2015年經使用者投票
# 徵才公司需嚴格符合中華民國勞基法規
#
# 1.需明確標示加班費計算方式
# 2.需明確說明最大工時，並需符合勞基法
# 3.採用責任制之職缺需為A.主管 B.系統研發工程師 C.維護工程師三種
#   (需說明工時)
#   (檢附呈報主管機關之文件內容)
#   (預計核備之主管機關)
#   三項文件均須公開
#   並公開給予勞工之責任制
#   (勞動合約)
#
#   以上條件均達成才可PO責任制職缺
#
# 處罰:
# 初犯:違者初犯刪文警告
#
# 二次PO文不更改相關內容
# 劣退文章，並永久水桶相關IP不得PO文
#
# 本條款不溯及既往
# 相關投票內容請見文章代碼:#1MWfUQbM【D】 禁止"發包"與家教類型文章，發包類型文章請至 Codejob 版發表。
# 【E】 不可徵求創業夥伴(請至創業板)
# 【F】 獵人頭(head hunter) 比照一間公司，請將職缺合併為一篇，標題以服務公司代替
# 【G】 派遣職缺+短期徵人與違反勞基法請勿張貼，派遣與短期請至CODEJOB徵外包商
#
#
#
# 注意:徵才公司若有實際發薪不如文章最低薪的狀況，經檢舉
#      版主詢問原ID後，若無回應會將公司名稱置底列作爭議公司區。
#
#      提醒徵才公司有爭議，勿以不實資料PO文，違者確認後永久水桶。
#      並永久封鎖所有IP與ID。
#
# -------------------------------------------------------------------
#
# 活動與分享文版規:
#
# 分為兩類:  免費與付費活動
#
# 由板主每個月一號發表兩篇文章，請在底下推文
# 勿超過五行，並利用縮網址功能(網址過長刪除推文)
#
# [情報]12月社群活動與免費APP與網站分享:主要分享免費資訊與免費軟體與網站
# [情報]12月訓練課程與付費APP與網站分享:主要分享付費課程與付費軟體與網站
#
# 以上推文內容若有不符合文章主旨者
#
# 處罰:板主修改刪文，觸犯水桶三日，累犯水桶一個月，再犯水桶一年
#      手機重複錯誤等，不處罰，板主主動更改。
#
# -----------------------------------------------
# 社交軟體群組管理板規
#
# 請注意以下事項
#
# 1.一個月(以月計算，1/31發完2/1日可再發)內
# 僅限發一篇文徵求一次，若一個月內發文兩次視同連續發表無意義文章刪文與水桶處理
#
# 2.禁止於社交軟體群組內涉及投資，新創，入股，販售課程以及其他非法犯罪事項，
# 唯獨書籍或網路免費課程不再此限，網路收費課程亦禁止，若有相關群組成員發現
# 該徵求ID水桶一年處分，並公告辦理，於檢舉後會請檢舉者刪除個資後
# 檢附相關對話紀錄。
#
# 註1：
# 類似Android讀書會之因場地因素需購買咖啡店飲料而非因讀書會收費之項目亦可
# 註2:
# 因群組其他人涉嫌違反第2條之規定群組創辦人需自行剔除
# 若有明顯疏於管理，禁止再於本板po文，另ID一併水桶一年
#
# 3.涉及收費課程等群組可於置底區推廣，不可單獨單篇文章，違反者初犯水桶五天，
# 次犯一個月，以保留單篇文章之公益推廣性質。
#
# 4.本管理辦法採取檢舉制，檢舉者需具名(ptt ID)並檢附圖片證據，
# 另本板與ptt站方不對任何群組背書與保證，所有群組之任何意見、行為、立場、看法
# 均予本板以及ptt無任何關聯。
# 若有緊急非法之事項，請立即告知板主公告以維使用者權利
# ---------------------------------------
# 一般板規:
#
# 【1】 勿發表 "無關" 軟體業之
#
#       1.文章      2.推噓文，註解文(推文從寬認定)
#
#       處罰:第一次刪文警告，嚴重者劣退，第二次水桶一個月。
#
# 本版不禁止與資訊產業相關之政治文，是否相關之標準以版務裁定為主。
# 亦請發文時盡量略為敘述政治內容與資訊產業之"直接"相關性以免爭議。
# (2014/4/15 依據使用者投票結果#1JHr3amX增訂)
#
#
# 【2】 發文、推文時對事不對人，勿人身攻擊
#
#       處罰:第一次警告雙方，並刪除不當言詞，第二次水桶一個月。
#            嚴重者，水桶一年，累犯加重處罰。
#
# 【3】 勿發表未滿40字，不滿三行內容(編輯後不滿仍算違規)
#       勿推圖形文，勿連續推相同語意與類似文章與推文
#
#       處罰:同版規1
#
# 【4】 禁止修他人推文。
#       除以下情況以外，嚴禁「刻意」修掉他人推文。
#
#        1.已事先在文章內文或使用者推文前推文聲明特定帳號不得推文。
#        2.因系統因素造成推文被修掉。（使用者申訴板務透過系統紀錄認定）
#        3.張爸推文
#        4.使用者自行要求刪除推文  (2011/7/17修訂)
#
#        處罰:初犯水桶三天，累犯者七天。
#
#        補註：如果認為使用者推文有人身攻擊的情況屬版規一範疇，
#              請向板務提出申訴，由板務裁決；勿自行修推文。
#
# 【5】 勿徵求取得盜版軟體，轉錄文章須經作者同意(智慧財產條款)
#
#       處罰:初犯刪文處分並水桶一個月，累犯第二次半年，第三次永久水桶。
#
#       看板投票發起辦法：(2014/4/15 增訂)
#
# 【6】 禁止非學術問卷，學術問卷採審核機制，請站內信板主審核後再行貼文
#
# 【7】 面試心得文需附上面試期間 例如:2016年 5月-7月 以不透漏個人隱私為原則
#
# 【8】 帳號水桶期間，所有分身應受相同發推文限制，
#       如發現於禁言期間使用分身進行看板活動，
#       受罰帳號與分身帳號將一同受到原水桶期間兩倍之懲罰，且計算日期重置。
#       如單一帳號加倍後水桶期限超過2年，將改判為10年水桶。
#       (2021/10/04 依據使用者投票結果#1XMWwDrU增訂)
#
# 【9】 於文章中有挑釁他人之語詞或刻意製造紛爭者
#       由當事人檢舉 是否挑釁由版主判定
#       判定成立 水桶一個月
#       (2021/10/04 依據使用者投票結果#1XMWwD0b增訂)
#       (只有個人對個人會處理 公司徵才不算在他人之列)
#
# --
# Every man for himself and God against them all.
#
# --
# ====================================================================================================
# 第 26 篇:
# 刪文會記錄在此篇
# 然後會置底方便板友查詢
# 廠商若有更改制度請站內信或推文告知
# 會補充說明
#
#
# 徵才自刪
#
#  作者  nzlchind (凸凸)                                         看板  Soft_Job
#  標題  【旺旺集團】徵求JAVA 、前端開發工程師
#  時間  Mon Jun 19 12:21:45 2017
#
# 文章代碼#1OzPTHI_---
# 作者  aand37 (jamesmisk)                                      看板  Soft_Job
# 標題  [徵才] EvenBot徵TechLeader & Senior Ui Design
# 時間  Wed Feb 15 11:36:31 2017
#
#
# 是否有加班費：公司採取責任制，但如果是公司因為需求要求加班會有加班補貼。
# ---
# 公司名稱，統編(中華民國以外註冊可免填):東捷資訊服務股份有限公司，23929058
# 公司地址(填寫詳細至號):台北市南港區三重路19-8號5樓
# 原文之推噓文表示以前無加班費
# 留存原噓文記錄
#
# 噓 marc47: 很久以前去應徵過，主管擺明加班沒加班費，還會翹二郎腿砍  05/23 04:46
# → marc47: 你薪資                                                  05/23 04:46
# ---
#
# 極點股份有限公司 (60k+) 加班費制度：無加班費制度設計(2016/10/17) elvisbw
# 2016/11/2日極點股分有限公司已站內信來函公司已添加加班費制度符合勞基法規範
# 並公告可繼續徵才
#
# 中菲電腦股份有限公司(40K~65K）加班費制度:補休(2016/08/19) kobedisel
#
# 奕力通信徵求系統開發工程師（50K/2Y）加班費制度:補休(2016/01/19) Dadai123
# 匯創紀有限公司(53111791) (45K~50K) 加班費制度:責任制(2016/01/27) Oppqr
#
# 橙遠科技 (30K-45K)   無加班費制度 (2016/01/29) louisabc
# (2016/02/05)更新修正有符合勞基法
#
# 汘澍文創徵PHP後端工程師(25k~70K/0~5y) 加班費制度:補休(2016/02/28)
# pokey0000000
#
# 普鴻資訊 java工程師（60k~100k) 加班費制度:責任制(2016/03/03)
# birddddd 公司統編:70584647
#
# 普鴻資訊股份有限公司
# 勞動基準法第30條第5項   未依規定置備勞工出勤紀錄
# 北市勞動字第10530385900號 105/04/28
#
# 杰星有限公司徵資深後端工程師台北市大安區市民大道四段102號6樓
# 加班費制度: 責任制 無加班費 (2016/03/18) seta2002
# 20160325 原PO再次發文 澄清正常上下班 按照勞基法發放加班費
#
# 博仁綜合醫院  台北市勞動局無加班費制度http://bola.gov.taipei/ct.asp?xItem=94627869&ctNode=76327&mp=116003(2016/03/25) 第15項  違反勞基法24與36條 未發加班費 七天未給予一天例假
# 府勞動字第10401081100號  Andy0609
#
# 爭議事項:
#
# 飛天數位科技(2016/3/21)使用者來信要求刪除相關關於飛天數位科技言論
# 內文含多數推文提起對飛天數位科技之現象，請應徵者面試該公司時須特別注意!
# 留意相關勞基法與相關法令，若有不法可至勞動局檢舉
#
# 飛天數位科技有限公司
# 負責人:廖永淦
# 勞動基準法第30條第1項   正常工時超過法令規定
# 北市勞動字第10530356500號
# 105/04/08
# 勞動基準法第30條第5項   未依規定置備勞工出勤紀錄
#
#
# --
# Every man for himself and God against them all.
#
# --
# ====================================================================================================
# 第 27 篇:
# 好吧 來新增版規投票
# Lushen & alihue 水桶我也先解了
# 對於投票項目有多的意見可以直接回這篇
# 例如該有的選項太少還是覺得有特殊規則 例如投票項目1
# 2跟3就是只有同意或者不同意
# 討論時間我看到9/22 投票時間為9/26~10/3
# 以下都不逤及以往
#
# 會有投票資格限制 就是進版限制再高一點
# 登入次數為200以上
#
# 這會是舉辦版上投票而不是西洽的那種推投統計喔
#
# =====投票項目1=====
# 對於版歸建議而需要討論的公告可以回
# ex
# 3/14 femlro       □ [公告] 徵求社群資訊
# 3/15 lovelycateye R: [公告] 徵求社群資訊
#
# 公告水桶類型的公告不能回應
# ex [公告] [討論] xxxxx 禁回
#
#
# =====投票項目2=====
# 增加分身條款
# 帳號水桶期間，所有分身應受相同發推文限制，
# 如發現於禁言期間使用分身進行看板活動，
# 受罰帳號與分身帳號將一同受到原水桶期間兩倍之懲罰，且計算日期重置。
# 如單一帳號加倍後水桶期限超過2年，將改判為10年水桶。
# (選項只有同意跟不同意)
#
# =====投票項目3=====
# 公司徵才不算在他人之列喔
# 對公司有利變成資方打手
# 對公司不利變成沒有公司可以發徵文
#
# → Hsins: 站規有：「（五）於文章中有挑釁他人之語詞或刻意製造紛爭   09/10 18:31
# → Hsins: 者。」，但沒有列出懲處內容，所以還是先修板規比較實在。   09/10 18:31
#
# 這邊挑釁我覺得 可能有人覺得有 有人覺得還不到
# 所以如果要新增這條的話 最終投票標題會是
#
# 於文章中有挑釁他人之語詞或刻意製造紛爭者
# 由當事人檢舉 是否挑釁由版主判定(這算是帝王條款)
# 水桶一個月
#
# (選項只有同意跟不同意)
#
# 順便抱怨一下我其實不太想處理挑釁舉報這類的邊界條件
# 又不是跟bilibili一樣有擦到禁詞就好了
# 所以挑釁言論如果選
# A.不同意 (代表之後舉報挑釁就會沒有法可以辦)
# B.同意 (就會變成版主主觀認定歐)
#
#
# 順便徵求一下版主
#
# --好 這個可以也請你回文新增這個的確是帝王 因為我也不想整天收到信
# xxxx引戰 挑釁 真的不喜歡可以投不同意
# 所以我才說是帝王條款 看到大概幾秒鐘就會決定處理了我看能不能由上面派人下來代管 然後舉辦投票吧
# 這樣好像才最公平我剛剛去看了一下小組長版 好像也徵求中 不知道是誰我看完之前的公告 有些特定內容的還是可以回
# 所以就乾脆拿出來投票了
# 最主要也是 真的很少人會用r去回公告啦這篇文章是可以用r回應的我覺得其實最公道的做法就是去申請上面下來代管到結束投票
# 我剛剛也去問了 不知道甚麼時候會有回應就是順便抱怨一下我其實不太想處理挑釁舉報這類的邊界條件
# 又不是跟bilibili一樣有擦到禁詞就好了
# 所以挑釁言論如果選不同意的話
# 代表之後舉報挑釁就會沒有法可以辦
# 選同意的話就會變成版主主觀認定從上任到現在檢舉挑釁的信很多喔
# 只是這種事情很麻煩 然後沒有人會那麼執著
# 年薪三百萬大大之前回公告被水桶 也是就這樣就過去了天下第一版規大會嗎這會是舉辦投票而不是推文投票喔
# ====================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, No.1 to No.27
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          27 non-null     object
#  1   author         27 non-null     object
#  2   post_date      27 non-null     object
#  3   push_num       27 non-null     object
#  4   article_links  26 non-null     object
#  5   content        27 non-null     object
# dtypes: object(6)
# memory usage: 1.5+ KB
# None
#                                        title        author post_date push_num  \
# No.1               Re: [請益] 好像不常聽到工程師研究程式交易？  joywilliamjo      5/08
# No.2               Re: [請益] 好像不常聽到工程師研究程式交易？   y2468101216      5/08        2
# No.3               Re: [請益] 好像不常聽到工程師研究程式交易？   qdullqidiot      5/08        2
# No.4                     Re: [請益] 接家業or回台當軟工         apage      5/08       16
# No.5               Re: [請益] 好像不常聽到工程師研究程式交易？        capita      5/08        5
# No.6               Re: [請益] 好像不常聽到工程師研究程式交易？       sorryla      5/09        1
# No.7                     [徵才] 全遠端美商 Swifteam    coedschool      5/09       15
# No.8                       [心得] 軟體考古系列：Redis        eliang      5/09       97
# No.9                     [討論] 閒聊文-為什麼前端這麼卷呀？     secretfly      5/09       31
# No.10                  [請益] 應該轉正還是去上課呢？（非本科）    denny41606      5/09       30
# No.11                Re: [討論] 閒聊文-為什麼前端這麼卷呀？       purin88      5/10       12
# No.12                Re: [討論] 閒聊文-為什麼前端這麼卷呀？       prag222      5/10        2
# No.13                         [請益] 北漂offer請益  seanho641015      5/10        6
# No.14                        [徵才] 中研院林哲揚老師徵才   filialpiety      5/11        4
# No.15                Re: [討論] 閒聊文-為什麼前端這麼卷呀？       gasbomb      5/11       27
# No.16                            [請益] 轉職職涯詢問       tin8420      5/11       26
# No.17                   [心得] 2023 找實習心得 - 全滅     pha123661      5/12       95
# No.18                     (本文已被刪除) [applebg]             -      5/12       X1
# No.19                          [討論] 花園種花-IT版       qooandy      5/13
# No.20                          [請益] 派遣外商該去嗎？        Luka77      5/13       12
# No.21                  [討論] 關於 Dcard ML 實習作業       Sixigma      5/14       10
# No.22  [心得] 2023 Yahoo Summer Intern Offer到手   Fantasylolz      5/14       17
# No.23               [推坑] 幣託技術總監：想賺錢？不要當軟體工程師        starkm      5/14
# No.24                  [請益] 會自己買辦公椅取代公司的椅子嗎？     givemoney      5/15       14
# No.25                 [公告] 本板板規  2017/4/10更新      MOONY135      8/04        4
# No.26                     [公告] 徵才不符板規或徵才自刪公司      MOONY135      8/04        7
# No.27               [公告] 版規投票討論(版上投票而不是推文投票)      MOONY135      9/10        6
#
#                                  article_links  \
# No.1               [Re: [請益] 好像不常聽到工程師研究程式交易？]
# No.2               [Re: [請益] 好像不常聽到工程師研究程式交易？]
# No.3               [Re: [請益] 好像不常聽到工程師研究程式交易？]
# No.4                     [Re: [請益] 接家業or回台當軟工]
# No.5               [Re: [請益] 好像不常聽到工程師研究程式交易？]
# No.6               [Re: [請益] 好像不常聽到工程師研究程式交易？]
# No.7                     [[徵才] 全遠端美商 Swifteam]
# No.8                       [[心得] 軟體考古系列：Redis]
# No.9                     [[討論] 閒聊文-為什麼前端這麼卷呀？]
# No.10                  [[請益] 應該轉正還是去上課呢？（非本科）]
# No.11                [Re: [討論] 閒聊文-為什麼前端這麼卷呀？]
# No.12                [Re: [討論] 閒聊文-為什麼前端這麼卷呀？]
# No.13                         [[請益] 北漂offer請益]
# No.14                        [[徵才] 中研院林哲揚老師徵才]
# No.15                [Re: [討論] 閒聊文-為什麼前端這麼卷呀？]
# No.16                            [[請益] 轉職職涯詢問]
# No.17                   [[心得] 2023 找實習心得 - 全滅]
# No.18                                     None
# No.19                          [[討論] 花園種花-IT版]
# No.20                          [[請益] 派遣外商該去嗎？]
# No.21                  [[討論] 關於 Dcard ML 實習作業]
# No.22  [[心得] 2023 Yahoo Summer Intern Offer到手]
# No.23               [[推坑] 幣託技術總監：想賺錢？不要當軟體工程師]
# No.24                  [[請益] 會自己買辦公椅取代公司的椅子嗎？]
# No.25                 [[公告] 本板板規  2017/4/10更新]
# No.26                     [[公告] 徵才不符板規或徵才自刪公司]
# No.27               [[公告] 版規投票討論(版上投票而不是推文投票)]
#
#                                                  content
# No.1   \n有做的其實比想像中的多，而且說賺的很大的也有\n不常聽到的原因大概是因為你就跟那些人不在...
# No.2   \n其實這跟股板比較有關。\n\n簡單說幾個我的觀點。\n\n1. 會賺錢的方法自己賺都來不...
# No.3   \n首先我就是讀商科 後來對寫程式有興趣\n所以跳槽工程師\n剛好又接觸到程式交易有興趣\n...
# No.4   \n我今年43歲，36歲從大陸回台灣，跟香港的姑姑一起合作開公司\n40歲決裂自己工作，現在...
# No.5   \n程式交易不少人在做，但工程師做程式交易的確實很少。\n\n簡單來說，程式交易的金融部份，...
# No.6   \n問題在於你想要用程式幫到你交易的哪個部分？\n\n如果你是要快進快出賺極短線的，你打得贏...
# No.7   \n公司名稱，統編(中華民國以外註冊可免填):\n\nSwifteam\n\nSwiftea...
# No.8   \n我一直覺得 Redis 在資料庫世界裡獨具一格。其他多數資料庫的中心思想不是表格就\n是...
# No.9   \n對岸的詞語 卷 好像就是一個很競爭的意思\n\n我發現好像台灣這邊的前端也差不多\n\n...
# No.10  \n各位好，之前曾經問過offer選擇的事情，很感謝版友們給我的回饋\n目前在猶豫是否應該在...
# No.11  \n我是覺得因為寫web(web前後端)程式比電機的簡單，容易入門，薪水隨便就3萬以上，學\...
# No.12  \n身為設計模式哥,我真的覺得設計模式也蠻easy的\n不過大部分人的話可能卡在學習這一關\...
# No.13  \n各位年薪300萬大大好，小弟我國立科大資工學士畢，相關工作經歷5年，有幸獲得兩個\nof...
# No.14  \n徵才文請依照以下格式填寫\n\n****特別注意!****\n\n有補休不等於符合勞基法...
# No.15  \n誒不是, 內捲的定義是什麼都沒搞清楚大家還可以討論得這麼開心 ==?\n內捲是 invo...
# No.16  \n今年由於是轉職第一年，年薪只有大概在60-65左右(很慘我知道)，老實說這樣的薪水，\n...
# No.17  \n# 前言\n\n背景：\n* 113 CS 學士 + 112 CS 碩一\n* Leet...
# No.18                                                 \n
# No.19  \n請大家多多傳唱，支持IT平權 哈～\n網頁版（包含歌詞解析）：https://vocus...
# No.20  \n小弟四大資工學士畢業，工作經驗約四年，之前都是在台灣公司。\n目前待業中，想找台北的外商...
# No.21  \n看到下面有篇大神有討論到這次 Dcard ML 實習作業，因為沒有收到團隊的具體反饋\n...
# No.22  \n看到版上蠻多篇分享實習面試的心得文章，就想說也來分享一下我自己的好了\n\n因為我對寫i...
# No.23  \n幣託技術總監 aka BigO因為當管理忘記的總監\n\n前陣子發生解題影片事件後\n\...
# No.24  \n工作這幾年來基本上都待在配備超爛椅子的地方\n\n每當腰酸背痛的時候，我就會思考是不是應...
# No.25  \n本板規部分沿用前版主TONYQ板規，生效日2016年1月1日----精神:極簡\n舊板規...
# No.26  \n刪文會記錄在此篇\n然後會置底方便板友查詢\n廠商若有更改制度請站內信或推文告知\n會補...
# No.27  \n好吧 來新增版規投票\nLushen & alihue 水桶我也先解了\n對於投票項目有...

# %% [markdown]
# <font color= #0fe9de size= 5 face="標楷體"> 將 DataFrame 匯入資料庫 </font>
